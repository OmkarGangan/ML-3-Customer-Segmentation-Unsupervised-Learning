# %% [raw]
# CUSTID : Identification of Credit Card holder
# BALANCE : Balance amount left in their account to make purchases
# BALANCEFREQUENCY : How frequently the Balance is updated, score between 0 and 1 (1 = frequently updated, 0 = not frequently updated)
# PURCHASES : Amount of purchases made from account
# ONEOFFPURCHASES : Maximum purchase amount done in one-go
# INSTALLMENTSPURCHASES : Amount of purchase done in installment
# CASHADVANCE : Cash in advance given by the user
# PURCHASESFREQUENCY : How frequently the Purchases are being made, score between 0 and 1 (1 = frequently purchased, 0 = not frequently purchased)
# ONEOFFPURCHASESFREQUENCY : How frequently Purchases are happening in one-go (1 = frequently purchased, 0 = not frequently purchased)
# PURCHASESINSTALLMENTSFREQUENCY : How frequently purchases in installments are being done (1 = frequently done, 0 = not frequently done)
# CASHADVANCEFREQUENCY : How frequently the cash in advance being paid
# CASHADVANCETRX : Number of Transactions made with "Cash in Advanced"
# PURCHASESTRX : Numbe of purchase transactions made
# CREDITLIMIT : Limit of Credit Card for user
# PAYMENTS : Amount of Payment done by user
# MINIMUM_PAYMENTS : Minimum amount of payments made by user
# PRCFULLPAYMENT : Percent of full payment paid by user
# TENURE : Tenure of credit card service for user

# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Read Data

# %%
df=pd.read_csv('CC GENERAL.csv')

# %% [markdown]
# # Data Inspection

# %%
df.head()
# Out:
#   CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  C10001    40.900749           0.818182      95.40              0.00
# 1  C10002  3202.467416           0.909091       0.00              0.00
# 2  C10003  2495.148862           1.000000     773.17            773.17
# 3  C10004  1666.670542           0.636364    1499.00           1499.00
# 4  C10005   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# 1                    0.000000                          0.000000
# 2                    1.000000                          0.000000
# 3                    0.083333                          0.000000
# 4                    0.083333                          0.000000
#
#    CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 0                0.000000                 0              2        1000.0
# 1                0.250000                 4              0        7000.0
# 2                0.000000                 0             12        7500.0
# 3                0.083333                 1              1        7500.0
# 4                0.000000                 0              1        1200.0
#
#       PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE
# 0   201.802084        139.509787          0.000000      12
# 1  4103.032597       1072.340217          0.222222      12
# 2   622.066742        627.284787          0.000000      12
# 3     0.000000               NaN          0.000000      12
# 4   678.334763        244.791237          0.000000      12

# %%
df.shape
# Out:
# (8950, 18)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8950 entries, 0 to 8949
# Data columns (total 18 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   CUST_ID                           8950 non-null   object
#  1   BALANCE                           8950 non-null   float64
#  2   BALANCE_FREQUENCY                 8950 non-null   float64
#  3   PURCHASES                         8950 non-null   float64
#  4   ONEOFF_PURCHASES                  8950 non-null   float64
#  5   INSTALLMENTS_PURCHASES            8950 non-null   float64
#  6   CASH_ADVANCE                      8950 non-null   float64
#  7   PURCHASES_FREQUENCY               8950 non-null   float64
#  8   ONEOFF_PURCHASES_FREQUENCY        8950 non-null   float64
#  9   PURCHASES_INSTALLMENTS_FREQUENCY  8950 non-null   float64
#  10  CASH_ADVANCE_FREQUENCY            8950 non-null   float64
#  11  CASH_ADVANCE_TRX                  8950 non-null   int64
#  12  PURCHASES_TRX                     8950 non-null   int64
#  13  CREDIT_LIMIT                      8949 non-null   float64
#  14  PAYMENTS                          8950 non-null   float64
#  15  MINIMUM_PAYMENTS                  8637 non-null   float64
#  16  PRC_FULL_PAYMENT                  8950 non-null   float64
#  17  TENURE                            8950 non-null   int64
# dtypes: float64(14), int64(3), object(1)
# memory usage: 1.2+ MB

# %%
df.describe().T
# Out:
#                                    count         mean          std        min  \
# BALANCE                           8950.0  1564.474828  2081.531879   0.000000
# BALANCE_FREQUENCY                 8950.0     0.877271     0.236904   0.000000
# PURCHASES                         8950.0  1003.204834  2136.634782   0.000000
# ONEOFF_PURCHASES                  8950.0   592.437371  1659.887917   0.000000
# INSTALLMENTS_PURCHASES            8950.0   411.067645   904.338115   0.000000
# CASH_ADVANCE                      8950.0   978.871112  2097.163877   0.000000
# PURCHASES_FREQUENCY               8950.0     0.490351     0.401371   0.000000
# ONEOFF_PURCHASES_FREQUENCY        8950.0     0.202458     0.298336   0.000000
# PURCHASES_INSTALLMENTS_FREQUENCY  8950.0     0.364437     0.397448   0.000000
# CASH_ADVANCE_FREQUENCY            8950.0     0.135144     0.200121   0.000000
# CASH_ADVANCE_TRX                  8950.0     3.248827     6.824647   0.000000
# PURCHASES_TRX                     8950.0    14.709832    24.857649   0.000000
# CREDIT_LIMIT                      8949.0  4494.449450  3638.815725  50.000000
# PAYMENTS                          8950.0  1733.143852  2895.063757   0.000000
# MINIMUM_PAYMENTS                  8637.0   864.206542  2372.446607   0.019163
# PRC_FULL_PAYMENT                  8950.0     0.153715     0.292499   0.000000
# TENURE                            8950.0    11.517318     1.338331   6.000000
#
#                                           25%          50%          75%  \
# BALANCE                            128.281915   873.385231  2054.140036
# BALANCE_FREQUENCY                    0.888889     1.000000     1.000000
# PURCHASES                           39.635000   361.280000  1110.130000
# ONEOFF_PURCHASES                     0.000000    38.000000   577.405000
# INSTALLMENTS_PURCHASES               0.000000    89.000000   468.637500
# CASH_ADVANCE                         0.000000     0.000000  1113.821139
# PURCHASES_FREQUENCY                  0.083333     0.500000     0.916667
# ONEOFF_PURCHASES_FREQUENCY           0.000000     0.083333     0.300000
# PURCHASES_INSTALLMENTS_FREQUENCY     0.000000     0.166667     0.750000
# CASH_ADVANCE_FREQUENCY               0.000000     0.000000     0.222222
# CASH_ADVANCE_TRX                     0.000000     0.000000     4.000000
# PURCHASES_TRX                        1.000000     7.000000    17.000000
# CREDIT_LIMIT                      1600.000000  3000.000000  6500.000000
# PAYMENTS                           383.276166   856.901546  1901.134317
# MINIMUM_PAYMENTS                   169.123707   312.343947   825.485459
# PRC_FULL_PAYMENT                     0.000000     0.000000     0.142857
# TENURE                              12.000000    12.000000    12.000000
#
#                                           max
# BALANCE                           19043.13856
# BALANCE_FREQUENCY                     1.00000
# PURCHASES                         49039.57000
# ONEOFF_PURCHASES                  40761.25000
# INSTALLMENTS_PURCHASES            22500.00000
# CASH_ADVANCE                      47137.21176
# PURCHASES_FREQUENCY                   1.00000
# ONEOFF_PURCHASES_FREQUENCY            1.00000
# PURCHASES_INSTALLMENTS_FREQUENCY      1.00000
# CASH_ADVANCE_FREQUENCY                1.50000
# CASH_ADVANCE_TRX                    123.00000
# PURCHASES_TRX                       358.00000
# CREDIT_LIMIT                      30000.00000
# PAYMENTS                          50721.48336
# MINIMUM_PAYMENTS                  76406.20752
# PRC_FULL_PAYMENT                      1.00000
# TENURE                               12.00000

# %%
# Checking Missing Values

# %%
df.isna().sum().sort_values(ascending=False)
# Out:
# MINIMUM_PAYMENTS                    313
# CREDIT_LIMIT                          1
# TENURE                                0
# PURCHASES_FREQUENCY                   0
# BALANCE                               0
# BALANCE_FREQUENCY                     0
# PURCHASES                             0
# ONEOFF_PURCHASES                      0
# INSTALLMENTS_PURCHASES                0
# CASH_ADVANCE                          0
# ONEOFF_PURCHASES_FREQUENCY            0
# PRC_FULL_PAYMENT                      0
# PURCHASES_INSTALLMENTS_FREQUENCY      0
# CASH_ADVANCE_FREQUENCY                0
# CASH_ADVANCE_TRX                      0
# PURCHASES_TRX                         0
# PAYMENTS                              0
# CUST_ID                               0
# dtype: int64

# %%
# Filling missing value with median

# %%
df.MINIMUM_PAYMENTS.fillna(df.MINIMUM_PAYMENTS.median(),inplace=True)

# %%
df.CREDIT_LIMIT.fillna(df.CREDIT_LIMIT.median(),inplace=True)

# %%
df.isna().sum().sort_values(ascending=False)
# Out:
# TENURE                              0
# PRC_FULL_PAYMENT                    0
# BALANCE                             0
# BALANCE_FREQUENCY                   0
# PURCHASES                           0
# ONEOFF_PURCHASES                    0
# INSTALLMENTS_PURCHASES              0
# CASH_ADVANCE                        0
# PURCHASES_FREQUENCY                 0
# ONEOFF_PURCHASES_FREQUENCY          0
# PURCHASES_INSTALLMENTS_FREQUENCY    0
# CASH_ADVANCE_FREQUENCY              0
# CASH_ADVANCE_TRX                    0
# PURCHASES_TRX                       0
# CREDIT_LIMIT                        0
# PAYMENTS                            0
# MINIMUM_PAYMENTS                    0
# CUST_ID                             0
# dtype: int64

# %%
# No missing values, Data is clean now

# %%
# Checking Outliers

# %%
i = 1
plt.figure(figsize=(20,20))
for x in df.columns[1:]:
    if i != 9:
        plt.subplot(3,3,i)
        sns.boxplot(y=df[x])
        plt.title(x)
    else:
        break
    i+=1

# %%
# No outliers, all data points are in clusters and other higher points are acceptable

# %%
# COnverting into numerical

# %%
def convert(s):
    return int(s[1:])

# %%
df.CUST_ID=df.CUST_ID.apply(convert)

# %% [markdown]
# # Selecting 2 Columns

# %% [raw]
# CUSTID : Identification of Credit Card holder
# BALANCE : Balance amount left in their account to make purchases

# %% [markdown]
# # Targeting customer card holder that have high balance left in their account

# %%
sns.scatterplot(x=df.BALANCE,y=df.CUST_ID)
# Out:
# <AxesSubplot:xlabel='BALANCE', ylabel='CUST_ID'>

# %%
X = df[['CUST_ID','BALANCE']]

# %%
X
# Out:
#       CUST_ID      BALANCE
# 0       10001    40.900749
# 1       10002  3202.467416
# 2       10003  2495.148862
# 3       10004  1666.670542
# 4       10005   817.714335
# ...       ...          ...
# 8945    19186    28.493517
# 8946    19187    19.183215
# 8947    19188    23.398673
# 8948    19189    13.457564
# 8949    19190   372.708075
#
# [8950 rows x 2 columns]

# %%
from sklearn.cluster import KMeans

wcss = []

for i in range(1,11):
    km = KMeans(n_clusters=i,random_state=10)
    km.fit(X)
    wcss.append(km.inertia_)
    
plt.plot(range(1,11),wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WSSE')#Within Cluster sum of squares
plt.show()

# %%
km = KMeans(n_clusters=4,random_state=10)
Y_pred=km.fit_predict(X)

# %%
km.n_iter_
# Out:
# 9

# %%
X['cluster'] = Y_pred
X
# Out:
# <ipython-input-26-bac23baaf98f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['cluster'] = Y_pred
#       CUST_ID      BALANCE  cluster
# 0       10001    40.900749        0
# 1       10002  3202.467416        0
# 2       10003  2495.148862        0
# 3       10004  1666.670542        0
# 4       10005   817.714335        0
# ...       ...          ...      ...
# 8945    19186    28.493517        1
# 8946    19187    19.183215        1
# 8947    19188    23.398673        1
# 8948    19189    13.457564        1
# 8949    19190   372.708075        1
#
# [8950 rows x 3 columns]

# %%
sns.scatterplot( data=X, x='CUST_ID', y='BALANCE',
           hue='cluster',palette="Set1")  

plt.scatter(km.cluster_centers_[:, 0], km.cluster_centers_[:, 1], 
            s = 300, c = 'yellow')
plt.show()

# %%
X['cluster']=X.cluster.map({0:'No',1:'No',2:'Target',3:'No'})
# Out:
# <ipython-input-28-becf9ce16358>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['cluster']=X.cluster.map({0:'No',1:'No',2:'Target',3:'No'})

# %%
X
# Out:
#       CUST_ID      BALANCE cluster
# 0       10001    40.900749      No
# 1       10002  3202.467416      No
# 2       10003  2495.148862      No
# 3       10004  1666.670542      No
# 4       10005   817.714335      No
# ...       ...          ...     ...
# 8945    19186    28.493517      No
# 8946    19187    19.183215      No
# 8947    19188    23.398673      No
# 8948    19189    13.457564      No
# 8949    19190   372.708075      No
#
# [8950 rows x 3 columns]

# %%
newdf1 = df.copy()

# %%
df
# Out:
#       CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0       10001    40.900749           0.818182      95.40              0.00
# 1       10002  3202.467416           0.909091       0.00              0.00
# 2       10003  2495.148862           1.000000     773.17            773.17
# 3       10004  1666.670542           0.636364    1499.00           1499.00
# 4       10005   817.714335           1.000000      16.00             16.00
# ...       ...          ...                ...        ...               ...
# 8945    19186    28.493517           1.000000     291.12              0.00
# 8946    19187    19.183215           1.000000     300.00              0.00
# 8947    19188    23.398673           0.833333     144.40              0.00
# 8948    19189    13.457564           0.833333       0.00              0.00
# 8949    19190   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                      95.40      0.000000             0.166667
# 1                       0.00   6442.945483             0.000000
# 2                       0.00      0.000000             1.000000
# 3                       0.00    205.788017             0.083333
# 4                       0.00      0.000000             0.083333
# ...                      ...           ...                  ...
# 8945                  291.12      0.000000             1.000000
# 8946                  300.00      0.000000             1.000000
# 8947                  144.40      0.000000             0.833333
# 8948                    0.00     36.558778             0.000000
# 8949                    0.00    127.040008             0.666667
#
#       ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                       0.000000                          0.083333
# 1                       0.000000                          0.000000
# 2                       1.000000                          0.000000
# 3                       0.083333                          0.000000
# 4                       0.083333                          0.000000
# ...                          ...                               ...
# 8945                    0.000000                          0.833333
# 8946                    0.000000                          0.833333
# 8947                    0.000000                          0.666667
# 8948                    0.000000                          0.000000
# 8949                    0.666667                          0.000000
#
#       CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 0                   0.000000                 0              2        1000.0
# 1                   0.250000                 4              0        7000.0
# 2                   0.000000                 0             12        7500.0
# 3                   0.083333                 1              1        7500.0
# 4                   0.000000                 0              1        1200.0
# ...                      ...               ...            ...           ...
# 8945                0.000000                 0              6        1000.0
# 8946                0.000000                 0              6        1000.0
# 8947                0.000000                 0              5        1000.0
# 8948                0.166667                 2              0         500.0
# 8949                0.333333                 2             23        1200.0
#
#          PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE
# 0      201.802084        139.509787          0.000000      12
# 1     4103.032597       1072.340217          0.222222      12
# 2      622.066742        627.284787          0.000000      12
# 3        0.000000        312.343947          0.000000      12
# 4      678.334763        244.791237          0.000000      12
# ...           ...               ...               ...     ...
# 8945   325.594462         48.886365          0.500000       6
# 8946   275.861322        312.343947          0.000000       6
# 8947    81.270775         82.418369          0.250000       6
# 8948    52.549959         55.755628          0.250000       6
# 8949    63.165404         88.288956          0.000000       6
#
# [8950 rows x 18 columns]

# %%
newdf1['cluster'] = X['cluster']

# %%
newdf1.head()
# Out:
#    CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0    10001    40.900749           0.818182      95.40              0.00
# 1    10002  3202.467416           0.909091       0.00              0.00
# 2    10003  2495.148862           1.000000     773.17            773.17
# 3    10004  1666.670542           0.636364    1499.00           1499.00
# 4    10005   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# 1                    0.000000                          0.000000
# 2                    1.000000                          0.000000
# 3                    0.083333                          0.000000
# 4                    0.083333                          0.000000
#
#    CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 0                0.000000                 0              2        1000.0
# 1                0.250000                 4              0        7000.0
# 2                0.000000                 0             12        7500.0
# 3                0.083333                 1              1        7500.0
# 4                0.000000                 0              1        1200.0
#
#       PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE cluster
# 0   201.802084        139.509787          0.000000      12      No
# 1  4103.032597       1072.340217          0.222222      12      No
# 2   622.066742        627.284787          0.000000      12      No
# 3     0.000000        312.343947          0.000000      12      No
# 4   678.334763        244.791237          0.000000      12      No

# %%
target1 = newdf1[newdf1.cluster=='Target']

# %%
target1
# Out:
#       CUST_ID       BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 15      10016   6886.213231                1.0    1611.70              0.00
# 21      10022   6369.531318                1.0    6359.95           5910.04
# 24      10025   5368.571219                1.0       0.00              0.00
# 28      10029   7152.864372                1.0     387.05            204.55
# 30      10031  12136.219960                1.0    3038.01           1013.20
# ...       ...           ...                ...        ...               ...
# 7684    17890   6482.798242                1.0       0.00              0.00
# 7764    17975  10856.483010                1.0      45.65             45.65
# 7962    18177  13318.659120                1.0    3504.74           3266.29
# 8151    18371   7215.195760                1.0       0.00              0.00
# 8705    18942   7302.672686                1.0       0.00              0.00
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 15                   1611.70   2301.491267             0.500000
# 21                    449.91    229.028245             1.000000
# 24                      0.00    798.949863             0.000000
# 28                    182.50   2236.145259             0.666667
# 30                   2024.81   3183.583301             1.000000
# ...                      ...           ...                  ...
# 7684                    0.00    706.910571             0.000000
# 7764                    0.00   5096.886673             0.083333
# 7962                  238.45   1306.849608             0.636364
# 8151                    0.00   7275.716281             0.000000
# 8705                    0.00  10762.707760             0.000000
#
#       ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 15                      0.000000                          0.500000
# 21                      0.916667                          1.000000
# 24                      0.000000                          0.000000
# 28                      0.166667                          0.416667
# 30                      0.166667                          1.000000
# ...                          ...                               ...
# 7684                    0.000000                          0.000000
# 7764                    0.083333                          0.000000
# 7962                    0.545455                          0.272727
# 8151                    0.000000                          0.000000
# 8705                    0.000000                          0.000000
#
#       CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 15                  0.166667                 4             11        8000.0
# 21                  0.333333                 6             92       11250.0
# 24                  0.363636                 4              0        6000.0
# 28                  0.833333                16              8       10500.0
# 30                  0.500000                10             64       13000.0
# ...                      ...               ...            ...           ...
# 7684                0.083333                 2              0        7500.0
# 7764                0.250000                 5              1       14500.0
# 7962                0.181818                 3             16       17500.0
# 8151                0.166667                 1              0        7500.0
# 8705                0.750000                19              0        9000.0
#
#          PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE cluster
# 15    1993.439277       2109.906490               0.0      12  Target
# 21    2077.959051       1659.775075               0.0      12  Target
# 24    1422.726707       1657.002877               0.0      11  Target
# 28    1601.448347       1648.851345               0.0      12  Target
# 30    4230.323491       3292.015030               0.0      12  Target
# ...           ...               ...               ...     ...     ...
# 7684  4630.593136       2439.310585               0.0      12  Target
# 7764  2670.733732       2917.469357               0.0      12  Target
# 7962  2594.820938       4762.246065               0.0      11  Target
# 8151   809.179193       1639.238121               0.0       6  Target
# 8705  3824.308564       2214.506825               0.0      12  Target
#
# [961 rows x 19 columns]

# %% [markdown]
# # Select 2 Columns

# %% [raw]
# PURCHASES : Amount of purchases made from account
# CUSTID : Identification of Credit Card holder

# %% [markdown]
# # Targeting Customer card holders that have made higher amount of purchases

# %%
sns.scatterplot(x=df.PURCHASES,y=df.CUST_ID)
# Out:
# <AxesSubplot:xlabel='PURCHASES', ylabel='CUST_ID'>

# %%
X = df[['CUST_ID','PURCHASES']]

# %%
X
# Out:
#       CUST_ID  PURCHASES
# 0       10001      95.40
# 1       10002       0.00
# 2       10003     773.17
# 3       10004    1499.00
# 4       10005      16.00
# ...       ...        ...
# 8945    19186     291.12
# 8946    19187     300.00
# 8947    19188     144.40
# 8948    19189       0.00
# 8949    19190    1093.25
#
# [8950 rows x 2 columns]

# %%
from sklearn.cluster import KMeans

wcss = []

for i in range(1,11):
    km = KMeans(n_clusters=i,random_state=10)
    km.fit(X)
    wcss.append(km.inertia_)
    
plt.plot(range(1,11),wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WSSE')#Within Cluster sum of squares
plt.show()

# %%
km = KMeans(n_clusters=3,random_state=10)
Y_pred=km.fit_predict(X)

# %%
X['cluster'] = Y_pred
X
# Out:
# <ipython-input-41-bac23baaf98f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['cluster'] = Y_pred
#       CUST_ID  PURCHASES  cluster
# 0       10001      95.40        0
# 1       10002       0.00        0
# 2       10003     773.17        0
# 3       10004    1499.00        0
# 4       10005      16.00        0
# ...       ...        ...      ...
# 8945    19186     291.12        1
# 8946    19187     300.00        1
# 8947    19188     144.40        1
# 8948    19189       0.00        1
# 8949    19190    1093.25        1
#
# [8950 rows x 3 columns]

# %%
sns.scatterplot( data=X, x='CUST_ID', y='PURCHASES',
           hue='cluster',palette="Set1")  

plt.scatter(km.cluster_centers_[:, 0], km.cluster_centers_[:, 1], 
            s = 300, c = 'yellow')
plt.show()

# %%
X['cluster']=X.cluster.map({0:'No',1:'No',2:'Target'})
# Out:
# <ipython-input-43-3a96664f085c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['cluster']=X.cluster.map({0:'No',1:'No',2:'Target'})

# %%
X
# Out:
#       CUST_ID  PURCHASES cluster
# 0       10001      95.40      No
# 1       10002       0.00      No
# 2       10003     773.17      No
# 3       10004    1499.00      No
# 4       10005      16.00      No
# ...       ...        ...     ...
# 8945    19186     291.12      No
# 8946    19187     300.00      No
# 8947    19188     144.40      No
# 8948    19189       0.00      No
# 8949    19190    1093.25      No
#
# [8950 rows x 3 columns]

# %%
newdf2 = df.copy()
newdf2['cluster'] = X['cluster']

# %%
newdf2.head()
# Out:
#    CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0    10001    40.900749           0.818182      95.40              0.00
# 1    10002  3202.467416           0.909091       0.00              0.00
# 2    10003  2495.148862           1.000000     773.17            773.17
# 3    10004  1666.670542           0.636364    1499.00           1499.00
# 4    10005   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# 1                    0.000000                          0.000000
# 2                    1.000000                          0.000000
# 3                    0.083333                          0.000000
# 4                    0.083333                          0.000000
#
#    CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 0                0.000000                 0              2        1000.0
# 1                0.250000                 4              0        7000.0
# 2                0.000000                 0             12        7500.0
# 3                0.083333                 1              1        7500.0
# 4                0.000000                 0              1        1200.0
#
#       PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE cluster
# 0   201.802084        139.509787          0.000000      12      No
# 1  4103.032597       1072.340217          0.222222      12      No
# 2   622.066742        627.284787          0.000000      12      No
# 3     0.000000        312.343947          0.000000      12      No
# 4   678.334763        244.791237          0.000000      12      No

# %%
target2 = newdf2[newdf2.cluster=='Target']

# %%
target2.head()
# Out:
#      CUST_ID       BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 6      10007    627.260806                1.0    7091.01           6402.63
# 120    10125   8504.876253                1.0    6724.26           4100.08
# 125    10131   2392.917738                1.0   12462.44          12462.44
# 138    10144  19043.138560                1.0   22009.92           9449.07
# 153    10159  13673.079610                1.0    9792.23           3959.81
#
#      INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 6                    688.38      0.000000             1.000000
# 120                 2624.18   1686.599777             1.000000
# 125                    0.00      0.000000             0.916667
# 138                12560.85      0.000000             1.000000
# 153                 5832.42   2444.445738             1.000000
#
#      ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 6                      1.000000                               1.0
# 120                    0.916667                               1.0
# 125                    0.916667                               0.0
# 138                    0.750000                               1.0
# 153                    0.750000                               1.0
#
#      CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 6                      0.00                 0             64       13500.0
# 120                    0.50                10             85       17000.0
# 125                    0.00                 0            217        2800.0
# 138                    0.00                 0            216       18000.0
# 153                    0.75                26            216       20000.0
#
#          PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE cluster
# 6     6354.314328        198.065894               1.0      12  Target
# 120   1888.756861       2167.446204               0.0      12  Target
# 125  11628.715570       2000.990921               0.0      12  Target
# 138  23018.575830      18621.013310               0.0      12  Target
# 153  11717.307940       6042.391629               0.0      12  Target

# %% [markdown]
# # Selecting 2 Columns

# %% [raw]
# PAYMENTS : Amount of Payment done by user
# CUSTID : Identification of Credit Card holder

# %% [markdown]
# # Targeting Customers that have made high payments

# %%
sns.scatterplot(x=df.PAYMENTS,y=df.CUST_ID)
# Out:
# <AxesSubplot:xlabel='PAYMENTS', ylabel='CUST_ID'>

# %%
X = df[['CUST_ID','PAYMENTS']]

# %%
from sklearn.cluster import KMeans

wcss = []

for i in range(1,11):
    km = KMeans(n_clusters=i,random_state=10)
    km.fit(X)
    wcss.append(km.inertia_)
    
plt.plot(range(1,11),wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WSSE')#Within Cluster sum of squares
plt.show()

# %%
km = KMeans(n_clusters=3,random_state=10)
Y_pred=km.fit_predict(X)

# %%
X['cluster'] = Y_pred
X
# Out:
# <ipython-input-53-bac23baaf98f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['cluster'] = Y_pred
#       CUST_ID     PAYMENTS  cluster
# 0       10001   201.802084        1
# 1       10002  4103.032597        1
# 2       10003   622.066742        1
# 3       10004     0.000000        1
# 4       10005   678.334763        1
# ...       ...          ...      ...
# 8945    19186   325.594462        0
# 8946    19187   275.861322        0
# 8947    19188    81.270775        0
# 8948    19189    52.549959        0
# 8949    19190    63.165404        0
#
# [8950 rows x 3 columns]

# %%
sns.scatterplot( data=X, x='CUST_ID', y='PAYMENTS',
           hue='cluster',palette="Set1")  

plt.scatter(km.cluster_centers_[:, 0], km.cluster_centers_[:, 1], 
            s = 300, c = 'yellow')
plt.show()

# %%
X['cluster']=X.cluster.map({0:'No',1:'No',2:'Target'})
# Out:
# <ipython-input-55-3a96664f085c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['cluster']=X.cluster.map({0:'No',1:'No',2:'Target'})

# %%
X
# Out:
#       CUST_ID     PAYMENTS cluster
# 0       10001   201.802084      No
# 1       10002  4103.032597      No
# 2       10003   622.066742      No
# 3       10004     0.000000      No
# 4       10005   678.334763      No
# ...       ...          ...     ...
# 8945    19186   325.594462      No
# 8946    19187   275.861322      No
# 8947    19188    81.270775      No
# 8948    19189    52.549959      No
# 8949    19190    63.165404      No
#
# [8950 rows x 3 columns]

# %%
newdf3 = df.copy()

# %%
newdf3['cluster'] = X['cluster']

# %%
newdf3.head()
# Out:
#    CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0    10001    40.900749           0.818182      95.40              0.00
# 1    10002  3202.467416           0.909091       0.00              0.00
# 2    10003  2495.148862           1.000000     773.17            773.17
# 3    10004  1666.670542           0.636364    1499.00           1499.00
# 4    10005   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# 1                    0.000000                          0.000000
# 2                    1.000000                          0.000000
# 3                    0.083333                          0.000000
# 4                    0.083333                          0.000000
#
#    CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 0                0.000000                 0              2        1000.0
# 1                0.250000                 4              0        7000.0
# 2                0.000000                 0             12        7500.0
# 3                0.083333                 1              1        7500.0
# 4                0.000000                 0              1        1200.0
#
#       PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE cluster
# 0   201.802084        139.509787          0.000000      12      No
# 1  4103.032597       1072.340217          0.222222      12      No
# 2   622.066742        627.284787          0.000000      12      No
# 3     0.000000        312.343947          0.000000      12      No
# 4   678.334763        244.791237          0.000000      12      No

# %%
target3 = newdf3[newdf3.cluster=='Target']

# %%
target3.head()
# Out:
#     CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 23    10024  3800.151377           0.818182    4248.35           3454.56
# 34    10035  3517.101616           0.727273     547.28              0.00
# 39    10040  1411.602230           0.454545     963.24            963.24
# 50    10052  4931.331857           1.000000     901.42            646.07
# 71    10074  2990.422186           0.909091    4523.27           1664.09
#
#     INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 23                  793.79   7974.415626             1.000000
# 34                  547.28      0.000000             1.000000
# 39                    0.00   6173.682877             0.083333
# 50                  255.35   8530.648614             0.625000
# 71                 2859.18  27296.485760             0.666667
#
#     ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 23                    0.083333                          0.916667
# 34                    0.000000                          1.000000
# 39                    0.083333                          0.000000
# 50                    0.375000                          0.250000
# 71                    0.500000                          0.583333
#
#     CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 23                0.333333                13             13        9000.0
# 34                0.000000                 0             14       11000.0
# 39                0.333333                 6              6        7500.0
# 50                0.875000                37              9       12000.0
# 71                0.833333                27             33        7000.0
#
#         PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE cluster
# 23   9479.043842       1425.426525          0.000000      12  Target
# 34   8735.607835      17862.558310          0.000000      12  Target
# 39  20071.075440        719.948985          0.333333      12  Target
# 50   8113.297346       1012.415961          0.000000       8  Target
# 71  28232.694460       1107.030803          0.454545      12  Target

# %% [markdown]
# # Select 2 Colummns

# %% [raw]
# CASHADVANCE : Cash in advance given by the user
# CUSTID : Identification of Credit Card holder

# %% [markdown]
# # Targeting Customers that make high advance payments

# %%
sns.scatterplot(x=df.CASH_ADVANCE,y=df.CUST_ID)
# Out:
# <AxesSubplot:xlabel='CASH_ADVANCE', ylabel='CUST_ID'>

# %%
X = df[['CUST_ID','CASH_ADVANCE']]

# %%
from sklearn.cluster import KMeans

wcss = []

for i in range(1,11):
    km = KMeans(n_clusters=i,random_state=10)
    km.fit(X)
    wcss.append(km.inertia_)
    
plt.plot(range(1,11),wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WSSE')#Within Cluster sum of squares
plt.show()

# %%
km = KMeans(n_clusters=3,random_state=10)
Y_pred=km.fit_predict(X)

# %%
X['cluster'] = Y_pred
# Out:
# <ipython-input-66-6018d039d696>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['cluster'] = Y_pred

# %%
sns.scatterplot( data=X, x='CUST_ID', y='CASH_ADVANCE',
           hue='cluster',palette="Set1")  

plt.scatter(km.cluster_centers_[:, 0], km.cluster_centers_[:, 1], 
            s = 300, c = 'yellow')
plt.show()

# %%
X['cluster']=X.cluster.map({0:'No',1:'No',2:'Target'})
# Out:
# <ipython-input-68-3a96664f085c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['cluster']=X.cluster.map({0:'No',1:'No',2:'Target'})

# %%
newdf4 = df.copy()

# %%
newdf4['cluster'] = X['cluster']

# %%
target4 = newdf4[newdf4.cluster=='Target']

# %%
target4
# Out:
#       CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 1       10002  3202.467416           0.909091       0.00              0.00
# 23      10024  3800.151377           0.818182    4248.35           3454.56
# 36      10037  7427.076941           1.000000       0.00              0.00
# 39      10040  1411.602230           0.454545     963.24            963.24
# 50      10052  4931.331857           1.000000     901.42            646.07
# ...       ...          ...                ...        ...               ...
# 8684    18921  1929.555023           1.000000     621.11            621.11
# 8705    18942  7302.672686           1.000000       0.00              0.00
# 8813    19053  3335.053583           0.700000       0.00              0.00
# 8857    19098  2330.222764           1.000000    1320.00              0.00
# 8941    19182  5967.475270           0.833333     214.55              0.00
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 1                       0.00   6442.945483             0.000000
# 23                    793.79   7974.415626             1.000000
# 36                      0.00   8873.375046             0.000000
# 39                      0.00   6173.682877             0.083333
# 50                    255.35   8530.648614             0.625000
# ...                      ...           ...                  ...
# 8684                    0.00   6691.286753             0.333333
# 8705                    0.00  10762.707760             0.000000
# 8813                    0.00   5823.467109             0.000000
# 8857                 1320.00  14926.790590             0.428571
# 8941                  214.55   8555.409326             0.833333
#
#       ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 1                       0.000000                          0.000000
# 23                      0.083333                          0.916667
# 36                      0.000000                          0.000000
# 39                      0.083333                          0.000000
# 50                      0.375000                          0.250000
# ...                          ...                               ...
# 8684                    0.333333                          0.000000
# 8705                    0.000000                          0.000000
# 8813                    0.000000                          0.000000
# 8857                    0.000000                          0.285714
# 8941                    0.000000                          0.666667
#
#       CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 1                   0.250000                 4              0        7000.0
# 23                  0.333333                13             13        9000.0
# 36                  0.727273                11              0        9000.0
# 39                  0.333333                 6              6        7500.0
# 50                  0.875000                37              9       12000.0
# ...                      ...               ...            ...           ...
# 8684                0.666667                29              5        6000.0
# 8705                0.750000                19              0        9000.0
# 8813                0.300000                 3              0        7000.0
# 8857                0.571429                10              3       10000.0
# 8941                0.666667                13              5        9000.0
#
#           PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE cluster
# 1      4103.032597       1072.340217          0.222222      12  Target
# 23     9479.043842       1425.426525          0.000000      12  Target
# 36     1636.361601       1986.843608          0.000000      11  Target
# 39    20071.075440        719.948985          0.333333      12  Target
# 50     8113.297346       1012.415961          0.000000       8  Target
# ...            ...               ...               ...     ...     ...
# 8684   2406.905963        549.027080          0.000000      12  Target
# 8705   3824.308564       2214.506825          0.000000      12  Target
# 8813    931.371718       1006.983314          0.000000      10  Target
# 8857   8157.666434        283.362434          0.200000       7  Target
# 8941    966.202912        861.949906          0.000000       6  Target
#
# [539 rows x 19 columns]

# %% [markdown]
# # Select 2 columns

# %% [raw]
# CREDITLIMIT : Limit of Credit Card for user
# CUSTID : Identification of Credit Card holder

# %% [markdown]
# # Selection customers that have high credit card limit

# %%
sns.scatterplot(x=df.CREDIT_LIMIT,y=df.CUST_ID)
# Out:
# <AxesSubplot:xlabel='CREDIT_LIMIT', ylabel='CUST_ID'>

# %%
X = df[['CUST_ID','CREDIT_LIMIT']]

# %%
from sklearn.cluster import KMeans

wcss = []

for i in range(1,11):
    km = KMeans(n_clusters=i,random_state=10)
    km.fit(X)
    wcss.append(km.inertia_)
    
plt.plot(range(1,11),wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WSSE')#Within Cluster sum of squares
plt.show()

# %%
km = KMeans(n_clusters=4,random_state=10)
Y_pred=km.fit_predict(X)

# %%
X['cluster'] = Y_pred
# Out:
# <ipython-input-80-6018d039d696>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['cluster'] = Y_pred

# %%
sns.scatterplot( data=X, x='CUST_ID', y='CREDIT_LIMIT',
           hue='cluster',palette="Set1")  

plt.scatter(km.cluster_centers_[:, 0], km.cluster_centers_[:, 1], 
            s = 300, c = 'yellow')
plt.show()

# %%
X['cluster']=X.cluster.map({0:'Target',1:'No',2:'No',3:'No'})
# Out:
# <ipython-input-82-659c4bc0fb74>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['cluster']=X.cluster.map({0:'Target',1:'No',2:'No',3:'No'})

# %%
newdf5 = df.copy()

# %%
newdf5['cluster'] = X['cluster']

# %%
newdf5.head()
# Out:
#    CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0    10001    40.900749           0.818182      95.40              0.00
# 1    10002  3202.467416           0.909091       0.00              0.00
# 2    10003  2495.148862           1.000000     773.17            773.17
# 3    10004  1666.670542           0.636364    1499.00           1499.00
# 4    10005   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# 1                    0.000000                          0.000000
# 2                    1.000000                          0.000000
# 3                    0.083333                          0.000000
# 4                    0.083333                          0.000000
#
#    CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 0                0.000000                 0              2        1000.0
# 1                0.250000                 4              0        7000.0
# 2                0.000000                 0             12        7500.0
# 3                0.083333                 1              1        7500.0
# 4                0.000000                 0              1        1200.0
#
#       PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE cluster
# 0   201.802084        139.509787          0.000000      12      No
# 1  4103.032597       1072.340217          0.222222      12      No
# 2   622.066742        627.284787          0.000000      12      No
# 3     0.000000        312.343947          0.000000      12      No
# 4   678.334763        244.791237          0.000000      12      No

# %%
target5 = newdf5[newdf5.cluster=='Target']

# %%
target5.head()
# Out:
#     CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 6     10007   627.260806           1.000000    7091.01           6402.63
# 9     10010   152.225975           0.545455    1281.60           1281.60
# 18    10019  1989.072228           1.000000     504.35            166.00
# 21    10022  6369.531318           1.000000    6359.95           5910.04
# 28    10029  7152.864372           1.000000     387.05            204.55
#
#     INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 6                   688.38      0.000000             1.000000
# 9                     0.00      0.000000             0.166667
# 18                  338.35      0.000000             0.666667
# 21                  449.91    229.028245             1.000000
# 28                  182.50   2236.145259             0.666667
#
#     ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 6                     1.000000                          1.000000
# 9                     0.166667                          0.000000
# 18                    0.083333                          0.583333
# 21                    0.916667                          1.000000
# 28                    0.166667                          0.416667
#
#     CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 6                 0.000000                 0             64       13500.0
# 9                 0.000000                 0              3       11000.0
# 18                0.000000                 0              9       13000.0
# 21                0.333333                 6             92       11250.0
# 28                0.833333                16              8       10500.0
#
#        PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE cluster
# 6   6354.314328        198.065894               1.0      12  Target
# 9   1164.770591        100.302262               0.0      12  Target
# 18  1720.837373        744.613395               0.0      12  Target
# 21  2077.959051       1659.775075               0.0      12  Target
# 28  1601.448347       1648.851345               0.0      12  Target

# %% [markdown]
# # Final Target Customers

# %%
target1.shape
# Out:
# (961, 19)

# %%
target2.shape
# Out:
# (173, 19)

# %%
target3.shape
# Out:
# (313, 19)

# %%
target4.shape
# Out:
# (539, 19)

# %%
target5.shape
# Out:
# (629, 19)

# %%
final_target = pd.concat([target1,target2,target3,target4,target5])

# %%
final_target.shape
# Out:
# (2615, 19)

# %%
# Removing similar records
final_target.drop_duplicates(inplace=True)

# %%
final_target.shape
# Out:
# (1630, 19)

# %% [markdown]
# # Final CSV of Target Customers

# %%
final_target.to_csv('Target_Customers.csv')

# %%
pd.read_csv('Target_Customers.csv',index_col=0)
# Out:
#       CUST_ID       BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 15      10016   6886.213231           1.000000    1611.70              0.00
# 21      10022   6369.531318           1.000000    6359.95           5910.04
# 24      10025   5368.571219           1.000000       0.00              0.00
# 28      10029   7152.864372           1.000000     387.05            204.55
# 30      10031  12136.219960           1.000000    3038.01           1013.20
# ...       ...           ...                ...        ...               ...
# 6328    16503    834.789126           1.000000       0.00              0.00
# 6484    16662   3086.119532           1.000000    1134.38            396.29
# 6638    16821   3043.796467           1.000000    1410.95           1270.97
# 8229    18450    161.926545           0.333333    1427.83           1427.83
# 8743    18982     40.960739           0.181818     472.75            431.37
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 15                   1611.70   2301.491267             0.500000
# 21                    449.91    229.028245             1.000000
# 24                      0.00    798.949863             0.000000
# 28                    182.50   2236.145259             0.666667
# 30                   2024.81   3183.583301             1.000000
# ...                      ...           ...                  ...
# 6328                    0.00    207.027078             0.000000
# 6484                  738.09   4323.275849             0.916667
# 6638                  139.98   1345.522967             0.666667
# 8229                    0.00      0.000000             0.333333
# 8743                   41.38      0.000000             0.181818
#
#       ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 15                      0.000000                          0.500000
# 21                      0.916667                          1.000000
# 24                      0.000000                          0.000000
# 28                      0.166667                          0.416667
# 30                      0.166667                          1.000000
# ...                          ...                               ...
# 6328                    0.000000                          0.000000
# 6484                    0.083333                          0.916667
# 6638                    0.416667                          0.416667
# 8229                    0.333333                          0.000000
# 8743                    0.181818                          0.090909
#
#       CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 15                  0.166667                 4             11        8000.0
# 21                  0.333333                 6             92       11250.0
# 24                  0.363636                 4              0        6000.0
# 28                  0.833333                16              8       10500.0
# 30                  0.500000                10             64       13000.0
# ...                      ...               ...            ...           ...
# 6328                0.090909                 2              0       13500.0
# 6484                0.166667                 2             22       12000.0
# 6638                0.250000                 4             13       11500.0
# 8229                0.000000                 0             12       14000.0
# 8743                0.000000                 0              7       13000.0
#
#          PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE cluster
# 15    1993.439277       2109.906490               0.0      12  Target
# 21    2077.959051       1659.775075               0.0      12  Target
# 24    1422.726707       1657.002877               0.0      11  Target
# 28    1601.448347       1648.851345               0.0      12  Target
# 30    4230.323491       3292.015030               0.0      12  Target
# ...           ...               ...               ...     ...     ...
# 6328   717.257211        233.199801               0.0      11  Target
# 6484  1492.992521        829.092375               0.0      12  Target
# 6638   834.226677        659.920499               0.0      12  Target
# 8229     0.000000        312.343947               0.0       6  Target
# 8743     0.000000        312.343947               0.0      11  Target
#
# [1630 rows x 19 columns]
